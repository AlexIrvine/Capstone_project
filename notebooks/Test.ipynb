# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\alexj\\OneDrive\\Data_Engineering\\Assignments\\Capstone_project\\Capstone_project\\data\\raw\\Antarctic blue whales, east Antarctic sector of the Southern Ocean.csv")
df.dtypes

df_processed = pd.read_csv("C:\\Users\\alexj\\OneDrive\\Data_Engineering\\Assignments\\Capstone_project\\Capstone_project\\data\processed\combined_cleaned_data.csv)
# Out:
# event-id                             int64
# visible                               bool
# timestamp                           object
# location-long                      float64
# location-lat                       float64
# argos:calcul-freq                  float64
# argos:iq                           float64
# argos:lc                            object
# argos:location-algorithm            object
# argos:nb-mes                         int64
# argos:sat-id                        object
# sensor-type                         object
# individual-taxon-canonical-name     object
# tag-local-identifier                 int64
# individual-local-identifier          int64
# study-name                          object
# study-timezone                      object
# study-local-timestamp               object
# dtype: object
